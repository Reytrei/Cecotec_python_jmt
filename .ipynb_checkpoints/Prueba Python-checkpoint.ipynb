# %%
import requests
import pandas as pd
import numpy as np

# %%
url = "https://cecobi.cecotec.cloud/ws/getstocksabanax.php"
output = "StockCecotecNacional.csv"

response = requests.get(url)
with open(output, 'wb') as f:
    f.write(response.content)

# %%
stock = pd.read_csv(output, sep= ";", encoding = 'ISO-8859-1')
stock.head()
# Out:
#   Referencia                                        Descripcion  \
# 0      05756  Aspirador vertical digital Conga Rockstar 890 ...
# 1      07737                      Colchón Flow Original 135x190
# 2      07071  Bicicleta estv°tica plegable DrumFit X-Cycle 1...
# 3      07072  Bicicleta esta´tica plegable DrumFit X-Cycle 2...
# 4      02628                         TV QLED V2 series VQU20043
#
#              Familia Padre                  Familia  \
# 0    Aspiración y Limpieza   Aspiradores verticales
# 1                 Descanso                 Descanso
# 2  Pendiente Clasificación  Pendiente Clasificación
# 3  Pendiente Clasificación  Pendiente Clasificación
# 4              Gama Marrón              Televisores
#
#                     Subfamilia  Stock Fisico  Stock Operativo  \
# 0  Aspiradores verticales BLDC             0                0
# 1                     Descanso            42               41
# 2      Pendiente Clasificación             0                0
# 3      Pendiente Clasificación          1453             1448
# 4             Televisores QLED          1325             1284
#
#    Stock Comercial  Mar  Puerto  Despachado
# 0                0    0       0           0
# 1               41    0       0           0
# 2                0    0       0           0
# 3             1448    0       0           0
# 4             1284    0       0         630

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4794 entries, 0 to 4793
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Referencia       4794 non-null   object
#  1   Descripcion      4791 non-null   object
#  2   Familia Padre    4665 non-null   object
#  3   Familia          4613 non-null   object
#  4   Subfamilia       4655 non-null   object
#  5   Stock Fisico     4794 non-null   int64
#  6   Stock Operativo  4794 non-null   int64
#  7   Stock Comercial  4794 non-null   int64
#  8   Mar              4794 non-null   int64
#  9   Puerto           4794 non-null   int64
#  10  Despachado       4794 non-null   int64
# dtypes: int64(6), object(5)
# memory usage: 412.1+ KB

# %%
stock_v = stock[stock['Referencia'].str.startswith('V')]
print(stock_v.shape)
stock_v.head()
# Out:
# (224, 11)
#    Referencia                            Descripcion Familia Padre  \
# 7       V0109   0614143387135-Evvo Android 55 UHD 4K   Gama Marrón
# 32      V0177         Robot aspirador EVVO R9D LASER           NaN
# 33      V0176          Robot aspirador EVVO R9 LASER           NaN
# 34      V0264   Secadora EVVO Nature S8X Bomba Calor           NaN
# 35      V0261  Secadora EVVO Nature S8C Condensación           NaN
#
#         Familia       Subfamilia  Stock Fisico  Stock Operativo  \
# 7   Televisores  Televisores LED            12               12
# 32          NaN              NaN           500              500
# 33          NaN              NaN           500              500
# 34          NaN              NaN             0                0
# 35          NaN              NaN             0                0
#
#     Stock Comercial  Mar  Puerto  Despachado
# 7                12    0       0           0
# 32              500    0       0           0
# 33              500    0       0           0
# 34                0    0       0          38
# 35                0    0       0          40

# %%
stock_p = stock[stock['Referencia'].str.startswith('P')]
print(stock_p.shape)
stock_p
# Out:
# (0, 11)
# Empty DataFrame
# Columns: [Referencia, Descripcion, Familia Padre, Familia, Subfamilia, Stock Fisico, Stock Operativo, Stock Comercial, Mar, Puerto, Despachado]
# Index: []

# %%
stock_num = stock[stock['Referencia'].str.match('^\d', na=False)]
print(stock_num.shape)
stock_num.head()
# Out:
# (4399, 11)
#   Referencia                                        Descripcion  \
# 0      05756  Aspirador vertical digital Conga Rockstar 890 ...
# 1      07737                      Colchón Flow Original 135x190
# 2      07071  Bicicleta estv°tica plegable DrumFit X-Cycle 1...
# 3      07072  Bicicleta esta´tica plegable DrumFit X-Cycle 2...
# 4      02628                         TV QLED V2 series VQU20043
#
#              Familia Padre                  Familia  \
# 0    Aspiración y Limpieza   Aspiradores verticales
# 1                 Descanso                 Descanso
# 2  Pendiente Clasificación  Pendiente Clasificación
# 3  Pendiente Clasificación  Pendiente Clasificación
# 4              Gama Marrón              Televisores
#
#                     Subfamilia  Stock Fisico  Stock Operativo  \
# 0  Aspiradores verticales BLDC             0                0
# 1                     Descanso            42               41
# 2      Pendiente Clasificación             0                0
# 3      Pendiente Clasificación          1453             1448
# 4             Televisores QLED          1325             1284
#
#    Stock Comercial  Mar  Puerto  Despachado
# 0                0    0       0           0
# 1               41    0       0           0
# 2                0    0       0           0
# 3             1448    0       0           0
# 4             1284    0       0         630

# %%
stock_resto = df_rest = stock[~(stock['Referencia'].str.match('^V', na=False) |
                  stock['Referencia'].str.match('^P', na=False) |
                  stock['Referencia'].str.match('^\d', na=False))]
print(stock_resto.shape)
stock_resto.head()
# Out:
# (171, 11)
#     Referencia                         Descripcion Familia Padre Familia  \
# 588      L4498                    SS23DE11-Shopper          Ropa    Ropa
# 598      L4949                  SS23PE17-Bandolera          Ropa    Ropa
# 606      L4262            SS23BB05-M-Blusa lencera          Ropa    Ropa
# 607      L4423            SS23CR06-M-Blusa lencera          Ropa    Ropa
# 608      L4504  SS23DN02-L-Vestido Camiseta Flecos          Ropa    Ropa
#
#     Subfamilia  Stock Fisico  Stock Operativo  Stock Comercial  Mar  Puerto  \
# 588       Ropa            22               20               20    0       0
# 598       Ropa            15               12               12    0       0
# 606       Ropa             0                0                0    0       0
# 607       Ropa             0                0                0    0       0
# 608       Ropa             0                0                0    0       0
#
#      Despachado
# 588           0
# 598           0
# 606           0
# 607           0
# 608           0

# %%
oportunidad_venta = stock_num[stock_num['Stock Fisico'] > 0]
print(oportunidad_venta.shape)
oportunidad_venta.head()
# Out:
# (2355, 11)
#   Referencia                                        Descripcion  \
# 0      07343                          Casco BrainGuard Sprinter
# 1      02201                                  Horno combi grill
# 2      02714  Vinoteca Bolero GrandSommelier 1230 CoolWood C...
# 4      02579                     TV Cecotec V1 series VQU10050S
# 6      07575                Colchón Flow PureVital 6990 135x190
#
#              Familia Padre                  Familia               Subfamilia  \
# 0         Cuidado del aire                      NaN                Raclettes
# 1  Pendiente Clasificación  Pendiente Clasificación  Pendiente Clasificación
# 2                      GAE                Vinotecas                Vinotecas
# 4              Gama Marrón              Televisores         Televisores QLED
# 6                 Descanso                 Descanso                 Descanso
#
#    Stock Fisico  Stock Operativo  Stock Comercial  Mar  Puerto  Despachado
# 0           500              499              499    0       0           0
# 1           155               40               40    0       0           0
# 2           263              262              262    0       0           0
# 4           215              207              207    0       0           0
# 6            62               62               62    0       0           0

# %%
stock_num['Futura'] = stock_num['Mar'] + stock_num['Puerto'] + stock_num['Despachado']
print(stock_num.shape)
stock_num.head()
# Out:
# (4570, 12)
# C:\Users\Juanma\AppData\Local\Temp\ipykernel_104460\2679531227.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_num['Futura'] = stock_num['Mar'] + stock_num['Puerto'] + stock_num['Despachado']
#   Referencia                                        Descripcion  \
# 0      07343                          Casco BrainGuard Sprinter
# 1      02201                                  Horno combi grill
# 2      02714  Vinoteca Bolero GrandSommelier 1230 CoolWood C...
# 3      01735  Cafeteras semi-atuomáticas instant-ccino 20 ch...
# 4      02579                     TV Cecotec V1 series VQU10050S
#
#              Familia Padre                  Familia               Subfamilia  \
# 0         Cuidado del aire                      NaN                Raclettes
# 1  Pendiente Clasificación  Pendiente Clasificación  Pendiente Clasificación
# 2                      GAE                Vinotecas                Vinotecas
# 3  Pendiente Clasificación  Pendiente Clasificación  Pendiente Clasificación
# 4              Gama Marrón              Televisores         Televisores QLED
#
#    Stock Fisico  Stock Operativo  Stock Comercial  Mar  Puerto  Despachado  \
# 0           500              499              499    0       0           0
# 1           155               40               40    0       0           0
# 2           263              262              262    0       0           0
# 3             0                0                0    0       0           0
# 4           215              207              207    0       0           0
#
#    Futura
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
futura_comercial_0 = stock_num[(stock_num['Stock Comercial'] == 0) & (stock_num['Futura'] ==0)]
print(futura_comercial_0.shape)
futura_comercial_0.head()
# Out:
# (2055, 12)
#    Referencia                                        Descripcion  \
# 3       01735  Cafeteras semi-atuomáticas instant-ccino 20 ch...
# 15      05436                         Robot aspirador Conga 3790
# 26      05091  Filtro de Alto Rendimiento Conga Duostock Easy...
# 27      04029                                          Sous vide
# 28      02611                                  TV 0 Series 0024S
#
#               Familia Padre                  Familia               Subfamilia  \
# 3   Pendiente Clasificación  Pendiente Clasificación  Pendiente Clasificación
# 15    Aspiración y Limpieza                   Robots       Robots aspiradores
# 26  Pendiente Clasificación  Pendiente Clasificación  Pendiente Clasificación
# 27  Pendiente Clasificación  Pendiente Clasificación  Pendiente Clasificación
# 28              Gama Marrón              Televisores          Televisores LED
#
#     Stock Fisico  Stock Operativo  Stock Comercial  Mar  Puerto  Despachado  \
# 3              0                0                0    0       0           0
# 15             0                0                0    0       0           0
# 26             0                0                0    0       0           0
# 27             0                0                0    0       0           0
# 28             0                0                0    0       0           0
#
#     Futura
# 3        0
# 15       0
# 26       0
# 27       0
# 28       0

# %%
stock_num['Remanente'] = stock_num['Stock Fisico'] - stock_num['Stock Comercial']
stock_num.head()
# Out:
# C:\Users\Juanma\AppData\Local\Temp\ipykernel_104460\964586685.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_num['Remanente'] = stock_num['Stock Fisico'] - stock_num['Stock Comercial']
#   Referencia                                        Descripcion  \
# 0      07343                          Casco BrainGuard Sprinter
# 1      02201                                  Horno combi grill
# 2      02714  Vinoteca Bolero GrandSommelier 1230 CoolWood C...
# 3      01735  Cafeteras semi-atuomáticas instant-ccino 20 ch...
# 4      02579                     TV Cecotec V1 series VQU10050S
#
#              Familia Padre                  Familia               Subfamilia  \
# 0         Cuidado del aire                      NaN                Raclettes
# 1  Pendiente Clasificación  Pendiente Clasificación  Pendiente Clasificación
# 2                      GAE                Vinotecas                Vinotecas
# 3  Pendiente Clasificación  Pendiente Clasificación  Pendiente Clasificación
# 4              Gama Marrón              Televisores         Televisores QLED
#
#    Stock Fisico  Stock Operativo  Stock Comercial  Mar  Puerto  Despachado  \
# 0           500              499              499    0       0           0
# 1           155               40               40    0       0           0
# 2           263              262              262    0       0           0
# 3             0                0                0    0       0           0
# 4           215              207              207    0       0           0
#
#    Futura  Remanente
# 0       0          1
# 1       0        115
# 2       0          1
# 3       0          0
# 4       0          8

# %%
stock_num['Porcentaje'] = np.where(stock_num['Stock Fisico'] == 0, 0, stock_num['Remanente'] / stock_num['Stock Fisico'])
stock_num['Porcentaje'] = stock_num['Porcentaje'] * 100
stock_num.head()
# Out:
# C:\Users\Juanma\AppData\Local\Temp\ipykernel_104460\3924573192.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_num['Porcentaje'] = np.where(stock_num['Stock Fisico'] == 0, 0, stock_num['Remanente'] / stock_num['Stock Fisico'])
# C:\Users\Juanma\AppData\Local\Temp\ipykernel_104460\3924573192.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_num['Porcentaje'] = stock_num['Porcentaje'] * 100
#   Referencia                                        Descripcion  \
# 0      07343                          Casco BrainGuard Sprinter
# 1      02201                                  Horno combi grill
# 2      02714  Vinoteca Bolero GrandSommelier 1230 CoolWood C...
# 3      01735  Cafeteras semi-atuomáticas instant-ccino 20 ch...
# 4      02579                     TV Cecotec V1 series VQU10050S
#
#              Familia Padre                  Familia               Subfamilia  \
# 0         Cuidado del aire                      NaN                Raclettes
# 1  Pendiente Clasificación  Pendiente Clasificación  Pendiente Clasificación
# 2                      GAE                Vinotecas                Vinotecas
# 3  Pendiente Clasificación  Pendiente Clasificación  Pendiente Clasificación
# 4              Gama Marrón              Televisores         Televisores QLED
#
#    Stock Fisico  Stock Operativo  Stock Comercial  Mar  Puerto  Despachado  \
# 0           500              499              499    0       0           0
# 1           155               40               40    0       0           0
# 2           263              262              262    0       0           0
# 3             0                0                0    0       0           0
# 4           215              207              207    0       0           0
#
#    Futura  Remanente  Porcentaje
# 0       0          1    0.200000
# 1       0        115   74.193548
# 2       0          1    0.380228
# 3       0          0    0.000000
# 4       0          8    3.720930
